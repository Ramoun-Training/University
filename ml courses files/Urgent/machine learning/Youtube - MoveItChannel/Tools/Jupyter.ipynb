# %% [markdown]
# # jupyter Tutorial
# <span sytle="color:red">**copying is better....believe me.*</span>

# %% [markdown]
# ### [JUPYTER Docs](https://jupyter.org/documentation.html)
# - [Official](https://jupyter.readthedocs.io/en/latest/index.html)
# - [readthedocs.io](https://jupyter-notebook.readthedocs.io/en/stable/index.html)
# - [nbviewer](https://nbviewer.jupyter.org/github/ipython/ipython/blob/3.x/examples/Notebook/Index.ipynb)

# %% [markdown]
# ### What is jupyter?
# - it is a spin-off ipython project (command shell for interactive computing) but supports more languages and kernals

# %% [markdown]
# ### What is the difference between an V.Environment and a Kernal?
# - V.Environment: is virtual folder with all packages used for a specific project or mulitple projects (but doesn't include tools like jupyter..etc)
# - Kernals: are virtual execution environments (E.g: jar for java..etc)[aka: compilers/interpreters]

# %% [markdown]
# ### Installation
#
# - using pip : use the following commeand `pip install jupyter`
#
# - using anaconda: it comes pre-installed with anaconda

# %% [markdown]
# ### Mardkdown Lingo
# - Docs: [Github documentation](https://help.github.com/en/github/writing-on-github/basic-writing-and-formatting-syntax), [Advanced docs](https://guides.github.com/features/mastering-markdown/)

# %% [markdown]
# ### Starting a notebook server
# - in the terminal type `jupyter notebokk`.
# - the following message should appear:
#   ```
# $ jupyter notebook
# [I 08:58:24.417 NotebookApp] Serving notebooks from local directory: /Users/catherine
# [I 08:58:24.417 NotebookApp] 0 active kernels
# [I 08:58:24.417 NotebookApp] The Jupyter Notebook is running at: http://localhost:8888/
# [I 08:58:24.417 NotebookApp] Use Control-C to stop this server and shut down all kernels (twice to skip confirmation)
# ```
# - the local server link to the notebook (http://localhost:8888)

# %% [markdown]
# ### Notebook's Server command line options
# - How do I open a specific Notebook?<br>
#      `jupyter notebook notebook.ipynb`
#
#
# - How do I start the Notebook using a custom IP or port?<br>
#     `jupyter notebook --port 9999`
#
#
# - How do I start the Notebook server without opening a browser?<br>
#     `jupyter notebook --no-browser`
#
#
# - How do I get help about Notebook server options?<br>
#     `jupyter notebook --help`

# %% [markdown]
# ### IPython Code is like:

# %%
while True:
    code = input(">>> ")
    exec(code)

# %% [markdown]
# ### A high level visual overview of project relationships-repos map
# ![A high level visual overview of project relationships-repos map](https://jupyter.readthedocs.io/en/latest/_images/repos_map.png)

# %% [markdown]
# ### What is jupyter is used for?
# - used for teaching:[github jupyterhub](https://github.com/jupyterhub/jupyterhub-deploy-teaching)
# - used for learning and taking notes
# - Educational purposes: [nbgrader](https://nbgrader.readthedocs.io/en/stable/)
# - [other purposes](https://jupyter.readthedocs.io/en/latest/projects/subprojects.html)
# - Research
# - Assignments for students
# - presentations

# %% [markdown]
# ### IPYTHON
# - IPython is the python kernal for jupyter and Spyder due to its _*`embeddability`*_
#
# - IPython provides a **rich architecture** for **interactive computing** with:
#
#     - A powerful interactive shell.
#     - A kernel for Jupyter.
#     - Support for interactive data visualization and use of GUI toolkits.
#     - Flexible, embeddable interpreters to load into your own projects.
#     - Easy to use, high performance tools for parallel computing.
#
# - more links:
#     - [IPython Website](https://ipython.org/)
#     - [A gallery of interesting IPython Notebooks](https://github.com/jupyter/jupyter/wiki/A-gallery-of-interesting-Jupyter-Notebooks)
#     - [Ex. of interesting notebooks for teaching how to code](https://github.com/yoavram/CS1001.py)
#     - [Trending jupyter notebooks on github]
#     - [IPython Documentation](https://ipython.readthedocs.io/en/stable/)
#     - [IPython Kernal for Jupyter](https://github.com/ipython/ipykernel)

# %% [markdown]
# ### Installation, Configuration, and Usage of different packages
# - [Website](https://jupyter.readthedocs.io/en/latest/projects/content-projects.html)

# %% [markdown]
# ### Upgrading IPython Notebook to Jupyter Notebook
# - If using Anaconda, update Jupyter using `conda`:<br>
# `conda update jupyter`
#
#
# - If using pip:<br>
# `pip install -U jupyter`

# %% [markdown]
# ### Contributor Guides
# - [Docs](https://jupyter.readthedocs.io/en/latest/contributor/content-contributor.html)
# - [Developer Guide](https://jupyter.readthedocs.io/en/latest/developer-docs/index.html#developer-guide)
# - [Full Guide](https://jupyter-notebook.readthedocs.io/en/stable/contributing.html)
# - [Open Source](https://jupyter.readthedocs.io/en/latest/developer-docs/contrib_guide_code.html)

# %% [markdown]
# ### Coding Style
# - [link](https://jupyter.readthedocs.io/en/latest/development_guide/coding_style.html)
# - A simple example:
# ```python
# class Foo(object):
#     # X does..., sensible default given:
#     x = 1
#     # y does..., default will be set by constructor
#     y = None
#     # z starts as an empty list, must be set in constructor
#     z = None
#
#     def __init__(self, y):
#         self.y = y
#         self.z = []
# ```

# %% [markdown]
# ### Bash Commands
# - ! : use bang in front of the command

# %%
# !pip list

# %% [markdown]
# ## Magix
# - % : single line magix
# - %% : cell magix

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %%time
print('testing how long does it takes to execute')

# %%
# %%time
for i in range(100000000):
    pass

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 0298-7111
#
#  Directory of C:\Users\Ramoun\Desktop\Urgent\machine learning\Youtube - MoveItChannel\Tools
#
# 02/23/2020  12:55 PM    <DIR>          .
# 02/23/2020  12:55 PM    <DIR>          ..
# 02/21/2020  09:21 AM    <DIR>          .ipynb_checkpoints
# 02/23/2020  12:55 PM            31,612 Jupyter.ipynb
# 02/21/2020  09:20 AM               555 Python.ipynb
#                2 File(s)         32,167 bytes
#                3 Dir(s)   3,873,173,504 bytes free

# %%
# %pwd

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

N= 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)

area = np.pi * (15 * np.random.rand(N))** 2

plt.scatter(x, y, s=area, c=colors ,alpha=0.5)
plt.show()

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(5,6))
df

# %%
# %%HTML
# <iframe width="937" height="380" src="https://www.youtube.com/embed/HW29067qVWk" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# %%time
# importing tkinter module 
from tkinter import * 
from tkinter.ttk import *
  
# creating tkinter window 
root = Tk() 
  
# Progress bar widget 
progress = Progressbar(root, orient = HORIZONTAL, 
              length = 400, mode = 'determinate') 
  
# Function responsible for the updation 
# of the progress bar value 
def bar(): 
    import time 
    progress['value'] = 20
    root.update_idletasks() 
    time.sleep(1) 
  
    progress['value'] = 40
    root.update_idletasks() 
    time.sleep(1) 
  
    progress['value'] = 50
    root.update_idletasks() 
    time.sleep(100000000) 
  
    progress['value'] = 60
    root.update_idletasks() 
    time.sleep(1) 
  
    progress['value'] = 80
    root.update_idletasks() 
    time.sleep(1) 
    progress['value'] = 100
  
progress.pack(pady = 10) 
  
# This button will initialize 
# the progress bar 
Button(root, text = 'Start', command = bar).pack(pady = 10) 
  
# infinite loop 
mainloop()

# %% [markdown]
# ## in the background
# - all .ipynb files are structured in .json

# %% [markdown]
# ## Languges
# - prog(python,julia,R,....)
# - markdown
# - latex

# %% [markdown]
# ## Example of Full Scientific Jupyter Notebook
# thie is a paragraph explaining a plot of a $sinc$ function
#
# _**the double dollar sign means give it its own line and center it**_
# $$
# f(x) = \frac{sinc(x)}{x}
# $$

# %%
# %config InlineBackend.figure_format = 'svg' 
import matplotlib.pyplot as plt
import numpy as np

pi = np.pi
x = np.linspace(-4*pi,4*pi,1000)

plt.xticks([-4*pi, -2*pi, 0, 2*pi, 4*pi],['$-4\pi$', '$-2\pi$', '$0$', '$2\pi$', '$4\pi$'])
plt.yticks([0,1],['$0$', '$1$'])
plt.rcParams['figure.figsize'] = [11,4]
plt.rcParams.update({'font.size':12})
plt.plot(x, np.sin(x)/x, label=r'$f(x)=\frac{\sin(x)}{x}$')
plt.ylim(-0.5, 1.5)
plt.legend(loc='best', fontsize=20)
plt.axhline(0, color='black', lw=2)
plt.title('the $sinc$ function')
plt.show()

# %% [markdown]
# ## Timing
# <iframe width="637" height="280" src="https://www.youtube.com/embed/iYp_C5W_ghE" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
